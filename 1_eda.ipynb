# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pokemon = pd.read_csv('/content/drive/MyDrive/MachineLearning/datasets/pokemon.csv')

# %% [markdown]
# 1. Structure of the data

# %%
pokemon.sample(4)
# Out:
#                                              abilities  against_bug  \
# 537            ['Guts', 'Inner Focus', 'Mold Breaker']          0.5
# 520             ['Big Pecks', 'Super Luck', 'Rivalry']          0.5
# 74   ['Rock Head', 'Sturdy', 'Sand Veil', 'Magnet P...          1.0
# 460                         ['Pressure', 'Pickpocket']          2.0
#
#      against_dark  against_dragon  against_electric  against_fairy  \
# 537           0.5             1.0               1.0            2.0
# 520           1.0             1.0               2.0            1.0
# 74            1.0             1.0               0.0            1.0
# 460           0.5             1.0               1.0            2.0
#
#      against_fight  against_fire  against_flying  against_ghost  ...  \
# 537            1.0           1.0             2.0            1.0  ...
# 520            1.0           1.0             1.0            0.0  ...
# 74             2.0           0.5             0.5            1.0  ...
# ...

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          801 non-null    object
#  1   against_bug        801 non-null    float64
#  2   against_dark       801 non-null    float64
#  3   against_dragon     801 non-null    float64
#  4   against_electric   801 non-null    float64
#  5   against_fairy      801 non-null    float64
#  6   against_fight      801 non-null    float64
#  7   against_fire       801 non-null    float64
#  8   against_flying     801 non-null    float64
#  9   against_ghost      801 non-null    float64
#  10  against_grass      801 non-null    float64
#  11  against_ground     801 non-null    float64
#  12  against_ice        801 non-null    float64
#  13  against_normal     801 non-null    float64
#  14  against_poison     801 non-null    float64
# ...

# %%
pokemon['is_legendary'].unique()
# Out:
# array([0, 1])

# %%
sns.histplot(data=pokemon, x=pokemon['is_legendary'])
# Out:
# <Axes: xlabel='is_legendary', ylabel='Count'>

# %%
pokemon['is_legendary'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='is_legendary'>

# %%
pokemon['generation'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
pokemon['generation'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='generation'>

# %%
pokemon['classfication'].unique()

# %%
pokemon['type1'].unique()
# Out:
# array(['grass', 'fire', 'water', 'bug', 'normal', 'poison', 'electric',
#        'ground', 'fairy', 'fighting', 'psychic', 'rock', 'ghost', 'ice',
#        'dragon', 'dark', 'steel', 'flying'], dtype=object)

# %%
sns.displot(pokemon['attack'], kind='kde')

# %%
pokemon['attack'].describe()
# Out:
# count    801.000000
# mean      77.857678
# std       32.158820
# min        5.000000
# 25%       55.000000
# 50%       75.000000
# 75%      100.000000
# max      185.000000
# Name: attack, dtype: float64

# %%
sns.boxplot(x=pokemon['attack'])
# Out:
# <Axes: xlabel='attack'>

# %%
sns.displot(pokemon['defense'], kind='kde')

# %%
sns.displot(pokemon['height_m'], kind='kde')

# %% [markdown]
# Above is the right skewed distribution.

# %%
pokemon['height_m'].describe()
# Out:
# count    781.000000
# mean       1.163892
# std        1.080326
# min        0.100000
# 25%        0.600000
# 50%        1.000000
# 75%        1.500000
# max       14.500000
# Name: height_m, dtype: float64

# %%
pokemon['height_m'].median()
# Out:
# 1.0

# %% [markdown]
# ![univariate.png](data:image/png;base64,...)

# %% [markdown]
# ## Multivariate Data Analysis

# %% [markdown]
# Let's know the correlation between `weight` and `is_legendary`

# %%
sns.scatterplot(data=pokemon, x='weight_kg', y='speed', hue='is_legendary')
# Out:
# <Axes: xlabel='weight_kg', ylabel='speed'>

# %%
sns.barplot(data=pokemon, x='is_legendary', y='sp_attack')
# Out:
# <Axes: xlabel='is_legendary', ylabel='sp_attack'>
